# %%
# !pip install crewai crewai-tools

# %%
# !crewai create crew first_project
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)
# Creating folder first_project...
# Cache expired or not found. Fetching provider data from the web...
# ...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. groq
# 5. ollama
# 6. watson
# 7. bedrock
# 8. azure
# 9. cerebras
# 10. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Select a model to use for Openai:
# 1. gpt-4
# 2. gpt-4o
# 3. gpt-4o-mini
# 4. o1-mini
# 5. o1-preview
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Enter your OPENAI API key (press Enter to skip):
# API keys and model saved to .env file
# Selected model: gpt-4
#   - Created first_project/.gitignore
#   - Created first_project/pyproject.toml
#   - Created first_project/README.md
#   - Created first_project/knowledge/user_preference.txt
# ...

# %%
# %cd first_project
# Out:
# /content/first_project

# %%
# !crewai install
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)
# Resolved 237 packages in 1ms
# Audited 233 packages in 0.29ms

# %%
import os
from google.colab import userdata
api_key = userdata.get('API')

os.environ["OPENAI_API_KEY"] = api_key
# !crewai run
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)
# Running the Crew
# /content/first_project/.venv/lib/python3.10/site-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# 1. AI LLMs (AI-based Legal Research Machines) are increasingly being adopted in the legal profession in 2024. They are systems developed to assist in legal research, analysis, and predictions, helping attorneys and law firms improve their efficiency and decision-making processes.
#
# ...
